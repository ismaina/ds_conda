# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D


#importing csv
df = pd.read_csv("C:\\Users\\maina\\Documents\\Digital Academy\\Data Science\\DS_Crash_Course_labs\\CDF_EXPENDITURE_ON_PROJECTS.csv")

# %%
df.head(6)
# Out:
#    objectid  index_  county district constituency  \
# 0         1     1.0  Kiambu   Kiambu   Githunguri
# 1         2     2.0  Kiambu   Kiambu   Githunguri
# 2         3     3.0  Kiambu   Kiambu   Githunguri
# 3         4     4.0  Kiambu   Kiambu   Githunguri
# 4         5     5.0  Kiambu   Kiambu   Githunguri
# 5         6     6.0  Kiambu   Kiambu   Githunguri
#
#                          project_name    location     sector  \
# 0                Kigumo Health Centre    Komothai     Health
# 1                 Ngewa Health Centre       Ngewa     Health
# 2                Gitiha Health Centre     Githiga     Health
# 3              Kiaibabu Health Centre       Ikinu     Health
# 4                  Ngeteti Dispensary  Githunguri     Health
# 5  Githunguri Township Primary School  Githunguri  Education
#
#                   mtfe_sector    econ1    ...     f2004_2005 f2005_2006  \
# 0  Human Resource Development  Capital    ...            0.0   300000.0
# ...

# %%
df.dtypes
# Out:
# objectid                   int64
# index_                   float64
# county                    object
# district                  object
# constituency              object
# project_name              object
# location                  object
# sector                    object
# mtfe_sector               object
# econ1                     object
# econ2                     object
# activity_to_bedone        object
# expected_output           object
# implementation_status     object
# remarks                   object
# estimated_cost           float64
# f2003_2004               float64
# f2004_2005               float64
# f2005_2006               float64
# f2006_2007               float64
# f2007_2008               float64
# f2008_2009               float64
# f2009_2010               float64
# total_amount             float64
# prox2                    float64
# y                        float64
# x                        float64
# dtype: object

# %%
df['sector'].value_counts().plot(kind='bar')

# %%
df.describe(include='all')
# Out:
#             objectid        index_ county  district constituency  \
# count   39054.000000  39040.000000  39041     39041        39041
# unique           NaN           NaN     47        71          210
# top              NaN           NaN   Meru  Machakos       Kwanza
# freq             NaN           NaN   1990      1621          573
# mean    19527.500000  25537.320312    NaN       NaN          NaN
# std     11274.063043  14833.015278    NaN       NaN          NaN
# min         1.000000      1.000000    NaN       NaN          NaN
# 25%      9764.250000  12622.750000    NaN       NaN          NaN
# 50%     19527.500000  25819.500000    NaN       NaN          NaN
# 75%     29290.750000  38573.250000    NaN       NaN          NaN
# max     39054.000000  50931.000000    NaN       NaN          NaN
#
#                project_name  location     sector                 mtfe_sector  \
# count                 39038     38466      39041                       38638
# ...

# %%
#Check null values
df.isna().sum()
# Out:
# objectid                     0
# index_                      14
# county                      13
# district                    13
# constituency                13
# project_name                16
# location                   588
# sector                      13
# mtfe_sector                416
# econ1                       13
# econ2                       13
# activity_to_bedone        1371
# expected_output           4730
# implementation_status     2090
# remarks                  19390
# estimated_cost             971
# f2003_2004                  11
# f2004_2005                  12
# f2005_2006                  11
# f2006_2007                  12
# f2007_2008                  12
# f2008_2009                  12
# f2009_2010                  11
# total_amount                11
# prox2                       11
# y                           11
# x                           11
# dtype: int64

# %%
df[['total_amount','estimated_cost']]
# Out:
#        total_amount  estimated_cost
# 0         2400000.0       3000000.0
# 1         1280012.0       2000000.0
# 2         3052000.0       3500000.0
# 3         3900130.0       4000000.0
# 4         1427000.0       2000000.0
# 5          350000.0       1450000.0
# 6         2600000.0       3000000.0
# 7         2950000.0       3330000.0
# 8          500000.0        800000.0
# 9          500000.0        700000.0
# 10        3500000.0       3500000.0
# 11        3220000.0       5000000.0
# 12        1850000.0       2000000.0
# 13        3650000.0       4274000.0
# 14        3850000.0       4000000.0
# 15        2700000.0       3500000.0
# 16        4250000.0       3200000.0
# 17         600000.0       1000000.0
# 18         100000.0        200000.0
# 19         100000.0        200000.0
# 20        1000000.0             0.0
# 21         100000.0        200000.0
# 22         232220.0        250000.0
# 23         100000.0        300000.0
# 24        3200000.0       1500000.0
# ...

# %%
df['sector'].value_counts().plot(kind='pie')

# %%
cnn = df.groupby(['county'])[['total_amount','estimated_cost']].sum()
sns.distplot(cnn['total_amount'],bins=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
corr = df.corr()

# %%
sns.heatmap(corr)

# %%
#sns.pairplot(df)

# %%
#Reg showing variation between estimated cost and actual amount for counties
byCounty = df.groupby('county')[['estimated_cost','total_amount','econ1']].sum()
sns.lmplot(x='estimated_cost',y='total_amount',data=byCounty)

# %%
#Showing regression
sns.relplot(x="estimated_cost", y="total_amount",size='econ1',data=df)

# %%
def linegraphfunction(dataplot, title, xlabel, ylabel, num):
  r = lambda: random.randint(0, 255)
  setStyles = ['-.', '--', '-', ':', 'o', '+']

  plt.figure()
  for i in range(0, num):
      plt.plot(years, dataplot.iloc[i], setStyles[i % 6], color='#%02X%02X%02X' % (r(), r(), r()),
               label=dataplot.index[i])

  plt.legend(loc="upper left")

  plt.title(title, fontsize=16, fontweight='bold')
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)

  plt.show()


# Grouped by County (Top 5, Lowest 5)
years = ['f2003_2004', 'f2004_2005', 'f2005_2006', 'f2006_2007', 'f2007_2008', 'f2008_2009', 'f2009_2010']
countyPlot = df.groupby(['county']).sum().sort_values('total_amount', ascending=False)[years]
linegraphfunction(countyPlot, "Yearly Costs for Top 10 Counties", "Years", "Total Funds", 10)

# %%
fig = df.hist(bins=15,
                 color='steelblue',
                 edgecolor='black', linewidth=1.0,
                 xlabelsize=10, ylabelsize=10,
                 xrot=45, yrot=0,
                 figsize=(10,9),
                 grid=False)

plt.tight_layout(rect=(0, 0, 1.5, 1.5))

# %%
amp = pd.read_csv("C:\\Users\\maina\\Documents\\Digital Academy\\Data Science\\DS_Crash_Course_labs\\Average_Monthly_Price_of_Food_Crops_Commodities_Scheduled_Horticultural_Crops_between_2012_to_2015.csv")
flowers = pd.read_csv("C:\\Users\\maina\\Documents\\Digital Academy\\Data Science\\DS_Crash_Course_labs\\Annual_Summary_of_Horticultural_Exports_Flowers_Fruit_and_Vegetables_between_20052014.csv")

# %%
amp.describe()
# Out:
#        Volume_in_Kgs     OBJECTID
# count    1145.000000  1145.000000
# mean       73.370306   572.000000
# std        36.564162   330.677335
# min        13.000000     0.000000
# 25%        50.000000   286.000000
# 50%        90.000000   572.000000
# 75%        95.000000   858.000000
# max       142.000000  1144.000000

# %%
amp['Values_in_Ksh'] = amp['Values_in_Ksh'].str.replace('KES','')

# %%
amp['Values_in_Ksh']
# Out:
# 0        2205.00
# 1         511.00
# 2         616.00
# 3        2833.00
# 4        3411.00
# 5        1043.00
# 6        1997.00
# 7        2163.00
# 8        2377.00
# 9        2349.00
# 10       1614.00
# 11       2737.00
# 12       2833.00
# 13       4063.00
# 14       2757.00
# 15       1445.00
# 16       1514.00
# 17        785.00
# 18        570.00
# 19        748.00
# 20       1392.00
# 21       2232.00
# 22       1328.00
# 23       2739.00
# 24        531.00
# 25        570.00
# 26       2754.00
# 27       4100.00
# 28        863.00
# 29       2142.00
#           ...
# 1115     6200.00
# 1116     5746.00
# 1117     5811.00
# 1118    11256.00
# 1119    10033.00
# 1120     6230.00
# 1121     2967.00
# 1122    12881.00
# 1123     3566.00
# 1124     3770.00
# 1125     2101.00
# 1126     3000.00
# 1127     2610.00
# 1128     2535.00
# 1129     6469.00
# 1130     3776.00
# 1131     3768.00
# 1132     6031.00
# 1133     6123.00
# 1134     5727.00
# 1135     5715.00
# ...

# %%
#amp['Values_in_Ksh']

# %%
flowers.describe()
# Out:
#                 Kgs          Kshs    OBJECTID
# count  1.700000e+02  1.700000e+02  170.000000
# mean   8.143009e+06  2.652703e+09   84.500000
# std    1.797833e+07  6.743005e+09   49.218899
# min    0.000000e+00  0.000000e+00    0.000000
# 25%    5.989391e+05  1.388786e+08   42.250000
# 50%    1.616177e+06  6.595743e+08   84.500000
# 75%    5.676979e+06  1.547970e+09  126.750000
# max    9.814500e+07  4.212156e+10  169.000000

# %%
flowers.dtypes
# Out:
# Commodity     object
# Type          object
# Kgs          float64
# Kshs         float64
# Date          object
# OBJECTID       int64
# dtype: object

# %%
flowers['Commodity'].value_counts()
sns.countplot(x='Commodity',data=flowers)

# %%
amp = pd.read_csv("C:\\Users\\maina\\Documents\\Digital Academy\\Data Science\\DS_Crash_Course_labs\\Average_Monthly_Price_of_Food_Crops_Commodities_Scheduled_Horticultural_Crops_between_2012_to_2015.csv")

# %%
amp.describe()
# Out:
#        Volume_in_Kgs     OBJECTID
# count    1145.000000  1145.000000
# mean       73.370306   572.000000
# std        36.564162   330.677335
# min        13.000000     0.000000
# 25%        50.000000   286.000000
# 50%        90.000000   572.000000
# 75%        95.000000   858.000000
# max       142.000000  1144.000000

# %%
amp.head(5)
# Out:
#   Produce_Variety   Commodity_Type       Unit  Volume_in_Kgs Values_in_Ksh  \
# 0    Horticulture         Cabbages    Ext Bag            126    KES2205.00
# 1    Horticulture  Cooking Bananas  Med Bunch             22     KES511.00
# 2    Horticulture     Ripe Bananas  Med Bunch             14     KES616.00
# 3    Horticulture          Carrots    Ext Bag            138    KES2833.00
# 4    Horticulture         Tomatoes     Lg Box             64    KES3411.00
#
#                      Date  OBJECTID
# 0  01/01/2012 12:00:00 AM         0
# 1  01/01/2012 12:00:00 AM         1
# 2  01/01/2012 12:00:00 AM         2
# 3  01/01/2012 12:00:00 AM         3
# 4  01/01/2012 12:00:00 AM         4

# %%
amp['Values_in_Ksh'] = amp['Values_in_Ksh'].str.replace('KES','')

# %%
amp['Values_in_Ksh'].astype('float64')
# Out:
# 0        2205.0
# 1         511.0
# 2         616.0
# 3        2833.0
# 4        3411.0
# 5        1043.0
# 6        1997.0
# 7        2163.0
# 8        2377.0
# 9        2349.0
# 10       1614.0
# 11       2737.0
# 12       2833.0
# 13       4063.0
# 14       2757.0
# 15       1445.0
# 16       1514.0
# 17        785.0
# 18        570.0
# 19        748.0
# 20       1392.0
# 21       2232.0
# 22       1328.0
# 23       2739.0
# 24        531.0
# 25        570.0
# 26       2754.0
# 27       4100.0
# 28        863.0
# 29       2142.0
#          ...
# 1115     6200.0
# 1116     5746.0
# 1117     5811.0
# 1118    11256.0
# 1119    10033.0
# 1120     6230.0
# 1121     2967.0
# 1122    12881.0
# 1123     3566.0
# 1124     3770.0
# 1125     2101.0
# 1126     3000.0
# 1127     2610.0
# 1128     2535.0
# 1129     6469.0
# 1130     3776.0
# 1131     3768.0
# 1132     6031.0
# 1133     6123.0
# 1134     5727.0
# 1135     5715.0
# 1136    12622.0
# 1137     9962.0
# 1138     6239.0
# ...

# %%
amp.describe()
# Out:
#        Volume_in_Kgs     OBJECTID
# count    1145.000000  1145.000000
# mean       73.370306   572.000000
# std        36.564162   330.677335
# min        13.000000     0.000000
# 25%        50.000000   286.000000
# 50%        90.000000   572.000000
# 75%        95.000000   858.000000
# max       142.000000  1144.000000
