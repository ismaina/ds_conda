# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
#importing csv
df = pd.read_csv("C:\\Users\\maina\\Documents\\Digital Academy\\Data Science\\DS_Crash_Course_labs\\CDF_EXPENDITURE_ON_PROJECTS.csv")

# %%
df.drop('econ2',axis=1,inplace=True)

# %% [raw]
# df.isna().sum()

# %%
df.dropna()
df.isna().sum()
# Out:
# objectid                     0
# index_                      14
# county                      13
# district                    13
# constituency                13
# project_name                16
# location                   588
# sector                      13
# mtfe_sector                416
# econ1                       13
# activity_to_bedone        1371
# expected_output           4730
# implementation_status     2090
# remarks                  19390
# estimated_cost             971
# f2003_2004                  11
# f2004_2005                  12
# f2005_2006                  11
# f2006_2007                  12
# f2007_2008                  12
# f2008_2009                  12
# f2009_2010                  11
# total_amount                11
# prox2                       11
# y                           11
# x                           11
# dtype: int64

# %%
df.head()
# Out:
#    objectid  index_  county district constituency            project_name  \
# 0         1     1.0  Kiambu   Kiambu   Githunguri    Kigumo Health Centre
# 1         2     2.0  Kiambu   Kiambu   Githunguri     Ngewa Health Centre
# 2         3     3.0  Kiambu   Kiambu   Githunguri    Gitiha Health Centre
# 3         4     4.0  Kiambu   Kiambu   Githunguri  Kiaibabu Health Centre
# 4         5     5.0  Kiambu   Kiambu   Githunguri      Ngeteti Dispensary
#
#      location  sector                 mtfe_sector    econ1    ...      \
# 0    Komothai  Health  Human Resource Development  Capital    ...
# 1       Ngewa  Health  Human Resource Development  Capital    ...
# 2     Githiga  Health  Human Resource Development  Capital    ...
# 3       Ikinu  Health  Human Resource Development  Capital    ...
# 4  Githunguri  Health  Human Resource Development  Capital    ...
#
#   f2004_2005 f2005_2006 f2006_2007 f2007_2008  f2008_2009  f2009_2010  \
# ...

# %%
col_convert = ['county','district','location','sector','mtfe_sector','econ1']
map(lambda x :df[x].astype['category'],col_convert)
df['county'].astype('category')
# Out:
# 0        Kiambu
# 1        Kiambu
# 2        Kiambu
# 3        Kiambu
# 4        Kiambu
# 5        Kiambu
# 6        Kiambu
# 7        Kiambu
# 8        Kiambu
# 9        Kiambu
# 10       Kiambu
# 11       Kiambu
# 12       Kiambu
# 13       Kiambu
# 14       Kiambu
# 15       Kiambu
# 16       Kiambu
# 17       Kiambu
# 18       Kiambu
# 19       Kiambu
# 20       Kiambu
# 21       Kiambu
# 22       Kiambu
# 23       Kiambu
# 24       Kiambu
# 25       Kiambu
# 26       Kiambu
# 27       Kiambu
# 28       Kiambu
# 29       Kiambu
#           ...
# 39024    Vihiga
# 39025    Vihiga
# 39026    Vihiga
# 39027    Vihiga
# 39028    Vihiga
# 39029    Vihiga
# 39030    Vihiga
# 39031    Vihiga
# 39032    Vihiga
# 39033    Vihiga
# 39034    Vihiga
# 39035    Vihiga
# 39036    Vihiga
# 39037    Vihiga
# 39038    Vihiga
# 39039    Vihiga
# 39040    Vihiga
# 39041    Vihiga
# 39042    Vihiga
# 39043    Vihiga
# 39044    Vihiga
# 39045    Vihiga
# 39046    Vihiga
# 39047    Vihiga
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39054 entries, 0 to 39053
# Data columns (total 26 columns):
# objectid                 39054 non-null int64
# index_                   39040 non-null float64
# county                   39041 non-null object
# district                 39041 non-null object
# constituency             39041 non-null object
# project_name             39038 non-null object
# location                 38466 non-null object
# sector                   39041 non-null object
# mtfe_sector              38638 non-null object
# econ1                    39041 non-null object
# activity_to_bedone       37683 non-null object
# expected_output          34324 non-null object
# implementation_status    36964 non-null object
# remarks                  19664 non-null object
# estimated_cost           38083 non-null float64
# f2003_2004               39043 non-null float64
# f2004_2005               39042 non-null float64
# ...

# %%
df['total_amount'] - df['estimated_cost']
df.head()
# Out:
#    objectid  index_  county district constituency            project_name  \
# 0         1     1.0  Kiambu   Kiambu   Githunguri    Kigumo Health Centre
# 1         2     2.0  Kiambu   Kiambu   Githunguri     Ngewa Health Centre
# 2         3     3.0  Kiambu   Kiambu   Githunguri    Gitiha Health Centre
# 3         4     4.0  Kiambu   Kiambu   Githunguri  Kiaibabu Health Centre
# 4         5     5.0  Kiambu   Kiambu   Githunguri      Ngeteti Dispensary
#
#      location  sector                 mtfe_sector    econ1    ...      \
# 0    Komothai  Health  Human Resource Development  Capital    ...
# 1       Ngewa  Health  Human Resource Development  Capital    ...
# 2     Githiga  Health  Human Resource Development  Capital    ...
# 3       Ikinu  Health  Human Resource Development  Capital    ...
# 4  Githunguri  Health  Human Resource Development  Capital    ...
#
#   f2004_2005 f2005_2006 f2006_2007 f2007_2008  f2008_2009  f2009_2010  \
# ...

# %%
df['county'].value_counts()
# Out:
# Meru               1990
# Bungoma            1784
# Machakos           1621
# Kakamega           1574
# Kitui              1443
# Kisii              1428
# Kiambu             1413
# Homa Bay           1335
# Makueni            1264
# Kericho            1202
# Uasin Gishu        1199
# Nakuru             1164
# Siaya              1159
# Bomet              1142
# Migori             1132
# Kisumu             1074
# Nandi               979
# Vihiga              972
# Murang'a            922
# Nyeri               911
# Busia               896
# Trans Nzoia         882
# Baringo             881
# West Pokot          831
# Kajiado             763
# Nyamira             756
# Embu                704
# Kirinyaga           703
# Marakwet_Elgeyo     682
# Nyandarua           582
# Taita Taveta        581
# Kilifi              571
# Nairobi             501
# Kwale               488
# Laikipia            421
# Marsabit            412
# Narok               394
# Wajir               345
# ...

# %%
mydat= ['f2003_2004','f2004_2005','f2005_2006']
byCounty = df.groupby('county')[['f2003_2004','f2004_2005','f2005_2006']].sum().plot(kind='line')
#byCounty = df.groupby('county')[['f2003_2004','f2004_2005','f2005_2006']].sum().plot(kind='line')

# %%
byCounty = df.groupby('county').sum()
#byCounty.max()

sns.barplot(y='total_amount',x='estimated_cost',data=byCounty)

# %%
#sns.countplot(x='econ1',data=df)
sns.lmplot(y='total_amount',x='estimated_cost', data=byCounty)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.regplot(x='total_amount', y='estimated_cost',data=byCounty)

# %%
df['mtfe_sector'].value_counts()
sns.countplot(x='mtfe_sector',data=df)

# %%
df['sector'].value_counts()
sns.countplot(x='sector',data=df)

# %%
df['econ1'].value_counts()
sns.countplot(x='econ1',data=df)

# %%
#cleaning implementation_status

df['implementation_status'] = df['implementation_status'].str.replace('On Going','Ongoing')
df['implementation_status'] = df['implementation_status'].str.replace('On going','Ongoing')
df['implementation_status'] = df['implementation_status'].str.replace('On-Going','Ongoing')
df['implementation_status'] = df['implementation_status'].str.replace('OnGoing','Ongoing')
df['implementation_status'] = df['implementation_status'].str.replace('Work Is Complete','Ongoing')
df['implementation_status'] = df['implementation_status'].str.replace('Work In Progress','Ongoing')
df['implementation_status'] = df['implementation_status'].str.replace('Incomplete','Ongoing')

df['implementation_status'] = df['implementation_status'].str.replace('Complete','Completed')
df['implementation_status'] = df['implementation_status'].str.replace('Completed ','Completed')
df['implementation_status'] = df['implementation_status'].str.replace('Completedd*','Completed')
df['implementation_status'].value_counts()
#sns.countplot(x='implementation_status',data=df)implementation_status
# Out:
# Completed                                                                                                                                 10285
# Ongoing                                                                                                                                   10176
# CompletedAnd In Use                                                                                                                        1278
# New                                                                                                                                        1034
# Completed& In Use                                                                                                                           775
# Stalled                                                                                                                                     560
# ...

# %%
df['county'].value_counts()
# Out:
# Meru               1990
# Bungoma            1784
# Machakos           1621
# Kakamega           1574
# Kitui              1443
# Kisii              1428
# Kiambu             1413
# Homa Bay           1335
# Makueni            1264
# Kericho            1202
# Uasin Gishu        1199
# Nakuru             1164
# Siaya              1159
# Bomet              1142
# Migori             1132
# Kisumu             1074
# Nandi               979
# Vihiga              972
# Murang'a            922
# Nyeri               911
# Busia               896
# Trans Nzoia         882
# Baringo             881
# West Pokot          831
# Kajiado             763
# Nyamira             756
# Embu                704
# Kirinyaga           703
# Marakwet_Elgeyo     682
# Nyandarua           582
# Taita Taveta        581
# Kilifi              571
# Nairobi             501
# Kwale               488
# Laikipia            421
# Marsabit            412
# Narok               394
# Wajir               345
# ...

# %%
df.head(5)
# Out:
#    objectid  index_  county district constituency            project_name  \
# 0         1     1.0  Kiambu   Kiambu   Githunguri    Kigumo Health Centre
# 1         2     2.0  Kiambu   Kiambu   Githunguri     Ngewa Health Centre
# 2         3     3.0  Kiambu   Kiambu   Githunguri    Gitiha Health Centre
# 3         4     4.0  Kiambu   Kiambu   Githunguri  Kiaibabu Health Centre
# 4         5     5.0  Kiambu   Kiambu   Githunguri      Ngeteti Dispensary
#
#      location  sector                 mtfe_sector    econ1    ...      \
# 0    Komothai  Health  Human Resource Development  Capital    ...
# 1       Ngewa  Health  Human Resource Development  Capital    ...
# 2     Githiga  Health  Human Resource Development  Capital    ...
# 3       Ikinu  Health  Human Resource Development  Capital    ...
# 4  Githunguri  Health  Human Resource Development  Capital    ...
#
#   f2004_2005 f2005_2006 f2006_2007 f2007_2008  f2008_2009  f2009_2010  \
# ...

# %%
sns.boxenplot(x='mtfe_sector',y='total_amount',data=df)

# %%
sns.boxplot(x='econ1',y='total_amount',data=df)
#compare day to bills in comparision to smokers

# %%
df['remarks'].value_counts()
# Out:
# -                                                                                                                                                                                                                                                                 1659
# in use                                                                                                                                                                                                                                                            1028
# In use                                                                                                                                                                                                                                                             669
# ...

# %%
years = ['f2003_2004', 'f2004_2005', 'f2005_2006', 'f2006_2007', 'f2007_2008', 'f2008_2009', 'f2009_2010']
countyPlot = df.groupby(['county']).sum().sort_values('total_amount', ascending=False)[years]
countyPlot
cnt = df['county'].value_counts()
cnt
#cnt = df['county'].value_counts().sort_values('total_amount', ascending=False)[years]
#sns.jointplot(x=cnt,y='total_amount',data=df,kind='reg') #linear fit; regresion
# Out:
# Meru               1990
# Bungoma            1784
# Machakos           1621
# Kakamega           1574
# Kitui              1443
# Kisii              1428
# Kiambu             1413
# Homa Bay           1335
# Makueni            1264
# Kericho            1202
# Uasin Gishu        1199
# Nakuru             1164
# Siaya              1159
# Bomet              1142
# Migori             1132
# Kisumu             1074
# Nandi               979
# Vihiga              972
# Murang'a            922
# Nyeri               911
# Busia               896
# Trans Nzoia         882
# Baringo             881
# West Pokot          831
# Kajiado             763
# Nyamira             756
# Embu                704
# Kirinyaga           703
# Marakwet_Elgeyo     682
# Nyandarua           582
# Taita Taveta        581
# Kilifi              571
# Nairobi             501
# Kwale               488
# Laikipia            421
# Marsabit            412
# Narok               394
# Wajir               345
# ...

# %%
def linegraphfunction(dataplot, title, xlabel, ylabel, num):
  r = lambda: random.randint(0, 255)
  setStyles = ['-.', '--', '-', ':', 'o', '+']

  plt.figure()
  for i in range(0, num):
      plt.plot(years, dataplot.iloc[i], setStyles[i % 6], color='#%02X%02X%02X' % (r(), r(), r()),
               label=dataplot.index[i])

  plt.legend(loc="upper left")

  plt.title(title, fontsize=16, fontweight='bold')
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)

  plt.show()


# Grouped by County (Top 5, Lowest 5)
years = ['f2003_2004', 'f2004_2005', 'f2005_2006', 'f2006_2007', 'f2007_2008', 'f2008_2009', 'f2009_2010']
countyPlot = df.groupby(['county']).sum().sort_values('total_amount', ascending=False)[years]
linegraphfunction(countyPlot, "Yearly Costs for Top 10 Counties", "Years", "Total Funds", 10)

# %%
# plot data
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
df.groupby(['total_amount','county']).count()['econ1'].unstack().plot(ax=ax)

# %%
countyPlot = df.groupby(['county']).sum().sort_values('total_amount', ascending=False)[years]

years.index
#list(map(lambda x: x * 2 , my_list))
#sns.relplot(x =(lambda y: y , years) ,y=df['total_amount'],hue='county',data=df,style='event')
#sns.lineplot(data=countyPlot,x = map(m,years),y = 'total_amount' ,palette="county", style='event')
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
map(lambda x :year[x],range(0,7))
